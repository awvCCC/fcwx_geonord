# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import calendar

# %%
path = r'C:\Users\student\Documents\Alistair CoAgMET Projects\Pythonstuff\fcwx'
os.chdir(path)

dat = r"C:\Users\student\Documents\Alistair CoAgMET Projects\Pythonstuff\fcwx\FCL_SNOW.dat"

df = pd.read_csv(dat)

df
# Out:
#        175  2018  365  1900  108.6    109  107.5    17.22    2963    8.6  \
# 0      175  2018  365  1905  108.6  109.0  107.5    17.22  2974.0   8.60
# 1      175  2018  365  1910  108.6  109.0  107.5    17.89  2949.0   8.61
# 2      175  2018  365  1915  108.6  109.0  107.5    17.56  2986.0   8.56
# 3      175  2018  365  1920  108.6  109.0  107.5  1130.00  3007.0   8.46
# 4      175  2018  365  1925  108.6  109.0  107.5    17.72  2994.0   8.44
# ...    ...   ...  ...   ...    ...    ...    ...      ...     ...    ...
# 74595  175  2019  259  1920  114.4  114.7  112.9  1142.00  3013.0  66.76
# 74596  175  2019  259  1925  114.4  114.7  112.9  1135.00  3013.0  66.71
# 74597  175  2019  259  1930  114.5  114.7  112.9  1133.00  3013.0  66.76
# 74598  175  2019  259  1935  114.4  114.7  112.9  1131.00  3013.0  66.39
# 74599  175  2019  259  1940  114.5  114.7  112.9  1130.00  3013.0  65.80
#
#          37.24    0    34.97  0.1     -.325  -222  -11.56  12.13
# ...

# %%
df.columns = ['unknown','year','jd','time','vw1_mm','vw2_mm','vw3_mm','wetness1','wetness2','airtemp','sd1_in',
             'QN1','sd2_in','QN2','sd3_in','QN3','geonnor','battery']

df['hour'] = df.time/100
df['minute'] = df.time % 100

df['date'] = df['year'].astype(str) + df['jd'].astype(str)
df
# Out:
#        unknown  year   jd  time  vw1_mm  vw2_mm  vw3_mm  wetness1  wetness2  \
# 0          175  2018  365  1905   108.6   109.0   107.5     17.22    2974.0
# 1          175  2018  365  1910   108.6   109.0   107.5     17.89    2949.0
# 2          175  2018  365  1915   108.6   109.0   107.5     17.56    2986.0
# 3          175  2018  365  1920   108.6   109.0   107.5   1130.00    3007.0
# 4          175  2018  365  1925   108.6   109.0   107.5     17.72    2994.0
# ...        ...   ...  ...   ...     ...     ...     ...       ...       ...
# 74595      175  2019  259  1920   114.4   114.7   112.9   1142.00    3013.0
# 74596      175  2019  259  1925   114.4   114.7   112.9   1135.00    3013.0
# 74597      175  2019  259  1930   114.5   114.7   112.9   1133.00    3013.0
# 74598      175  2019  259  1935   114.4   114.7   112.9   1131.00    3013.0
# 74599      175  2019  259  1940   114.5   114.7   112.9   1130.00    3013.0
#
# ...

# %%
#df['new_date'] = (pd.to_datetime((df.date // 1000).astype(str)) + pd.to_datetime(df.date % 1000, unit='D'))
#julian = df.date.str[4:].str.extract('([1-9][0-9]?[0-9]?)')
#df['new_date'] = df.date.str[:4] + '-' + julian
#df['new_date'] = pd.to_datetime(df.date, format = '%Y-%j')
#df

def JulianDate_to_MMDDYYY(y,jd):
    month = 1
    day = 0
    while jd - calendar.monthrange(y,month)[1] > 0 and month <= 12:
        jd = jd - calendar.monthrange(y,month)[1]
        month = month + 1
    return month,jd,y
n=0
for index,rows in df.iterrows():
    df['date'][n] =  JulianDate_to_MMDDYYY(df.year[n],df.jd[n])
    n=n+1
# Out:
# C:\Users\student\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
for x in range(len(df.wetness1)):
    if df.wetness1[x] < 500:
        print('Moisture last detected on ' + str(df.date[x]) + ' at ' + str(df.time[x]))
# Out:
# Moisture last detected on (12, 31, 2018) at 1905
# Moisture last detected on (12, 31, 2018) at 1910
# Moisture last detected on (12, 31, 2018) at 1915
# Moisture last detected on (12, 31, 2018) at 1925
# Moisture last detected on (12, 31, 2018) at 1930
# Moisture last detected on (12, 31, 2018) at 1935
# Moisture last detected on (12, 31, 2018) at 1940
# Moisture last detected on (12, 31, 2018) at 1945
# Moisture last detected on (12, 31, 2018) at 1950
# Moisture last detected on (12, 31, 2018) at 1955
# Moisture last detected on (12, 31, 2018) at 2000
# Moisture last detected on (12, 31, 2018) at 2005
# Moisture last detected on (12, 31, 2018) at 2010
# Moisture last detected on (12, 31, 2018) at 2015
# Moisture last detected on (12, 31, 2018) at 2020
# Moisture last detected on (12, 31, 2018) at 2025
# Moisture last detected on (12, 31, 2018) at 2030
# Moisture last detected on (12, 31, 2018) at 2035
# Moisture last detected on (12, 31, 2018) at 2040
# ...
